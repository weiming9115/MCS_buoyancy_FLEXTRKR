# %%
import os
import sys
import xarray as xr
import numpy as np
from numpy import unravel_index
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
from matplotlib.font_manager import FontProperties
from datetime import datetime
from pathlib import Path
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
from matplotlib.patches import Rectangle

import cartopy.crs as ccrs
import cartopy.feature as cfeat
from cartopy.util import add_cyclic_point
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER

import warnings

# %%
warnings.filterwarnings('ignore')

# %%
# bins for BL_CAPE and BL_SUBSAT
bins_cape = np.arange(-15,10,0.5)
bins_subsat = np.arange(-5,25,0.5)
bins_samples = np.zeros((3, 6, len(bins_cape)-1, len(bins_subsat)-1)) # (area_type, mcs_phase, cape, subsat)
tag_sum = np.copy(bins_samples)


year_sel = 2001
env_dir = Path('/scratch/wmtsai/temp_mcs/mcs_stats/envs_track/{}/tropics_extend'.format(year_sel))
files = list(env_dir.glob('*.LD.nc'))

for file in files[:1]:
    
    mcs_env = xr.open_dataset(file)

    # define stratiform as pixels with rainfall < 0.5mm/hr, Tb < 241 K
    
    for phase in mcs_env.mcs_phase.values:
        
        data_phase = mcs_env.sel(mcs_phase=phase)
        thetae_bl = data_phase.thetae_bl
        thetae_lt = data_phase.thetae_lt
        thetae_sat_lt = data_phase.thetae_sat_lt
        sp = data_phase.SP/100 #hPa

        delta_pl=sp-100-400
        delta_pb=100
        wb=(delta_pb/delta_pl)*np.log((delta_pl+delta_pb)/delta_pb)
        wl=1-wb

        BL_CAPE = wb*(thetae_bl - thetae_sat_lt)/thetae_sat_lt*340 # (K)
        BL_SUBSAT = wl*(thetae_sat_lt - thetae_lt)/thetae_sat_lt*340 # (K)

        # define convective and stratiform pixels 
        prec = data_phase.precipitationCal
        tb = data_phase.tb
        conv_pix = prec.where(((prec >= 0.5) & (tb < 241)), 0)
        strat_pix = prec.where((prec < 0.5) & (tb < 241) & ())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 20
#      16 # define stratiform as pixels with rainfall < 0.5mm/hr, Tb < 241 K
#      18 for phase in mcs_env.mcs_phase.values:
# ---> 20     data_sub = mcs_env.isel(mcs_phase=phase)
#      21     data = xr.open_dataset(fid_envs_track)
#      22     thetae_bl = data.thetae_bl
#
# File ~/.conda/envs/wm_base/lib/python3.11/site-packages/xarray/core/dataset.py:2973, in Dataset.isel(self, indexers, drop, missing_dims, **indexers_kwargs)
#    2971 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "isel")
#    2972 if any(is_fancy_indexer(idx) for idx in indexers.values()):
# -> 2973     return self._isel_fancy(indexers, drop=drop, missing_dims=missing_dims)
#    2975 # Much faster algorithm for when all indexers are ints, slices, one-dimensional
#    2976 # lists, or zero or one-dimensional np.ndarray's
#    2977 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#
# File ~/.conda/envs/wm_base/lib/python3.11/site-packages/xarray/core/dataset.py:3029, in Dataset._isel_fancy(self, indexers, drop, missing_dims)
#    3025 var_indexers = {
#    3026     k: v for k, v in valid_indexers.items() if k in var.dims
#    3027 }
#    3028 if var_indexers:
# -> 3029     new_var = var.isel(indexers=var_indexers)
#    3030     # drop scalar coordinates
#    3031     # https://github.com/pydata/xarray/issues/6554
#    3032     if name in self.coords and drop and new_var.ndim == 0:
#
# File ~/.conda/envs/wm_base/lib/python3.11/site-packages/xarray/core/variable.py:1033, in Variable.isel(self, indexers, missing_dims, **indexers_kwargs)
#    1030 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    1032 key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1033 return self[key]
#
# File ~/.conda/envs/wm_base/lib/python3.11/site-packages/xarray/core/variable.py:797, in Variable.__getitem__(self, key)
#     784 def __getitem__(self, key) -> Self:
#     785     """Return a new Variable object whose contents are consistent with
#     786     getting the provided key from the underlying data.
#     787
#    (...)
#     795     array `x.values` directly.
#     796     """
# --> 797     dims, indexer, new_order = self._broadcast_indexes(key)
#     798     indexable = as_indexable(self._data)
#     800     data = indexing.apply_indexer(indexable, indexer)
#
# File ~/.conda/envs/wm_base/lib/python3.11/site-packages/xarray/core/variable.py:642, in Variable._broadcast_indexes(self, key)
#     638 # Detect it can be mapped as an outer indexer
#     639 # If all key is unlabeled, or
#     640 # key can be mapped as an OuterIndexer.
#     641 if all(not isinstance(k, Variable) for k in key):
# --> 642     return self._broadcast_indexes_outer(key)
#     644 # If all key is 1-dimensional and there are no duplicate labels,
#     645 # key can be mapped as an OuterIndexer.
#     646 dims = []
#
# File ~/.conda/envs/wm_base/lib/python3.11/site-packages/xarray/core/variable.py:724, in Variable._broadcast_indexes_outer(self, key)
#     721             (k,) = np.nonzero(k)
#     722     new_key.append(k)
# --> 724 return dims, OuterIndexer(tuple(new_key)), None
#
# File ~/.conda/envs/wm_base/lib/python3.11/site-packages/xarray/core/indexing.py:434, in OuterIndexer.__init__(self, key)
#     432 elif is_duck_array(k):
#     433     if not np.issubdtype(k.dtype, np.integer):
# --> 434         raise TypeError(
#     435             f"invalid indexer array, does not have integer dtype: {k!r}"
#     436         )
#     437     if k.ndim > 1:  # type: ignore[union-attr]
#     438         raise TypeError(
#     439             f"invalid indexer array for {type(self).__name__}; must be scalar "
#     440             f"or have 1 dimension: {k!r}"
#     441         )
#
# TypeError: invalid indexer array, does not have integer dtype: array('CCS', dtype='<U3')

# %%
tmp = mcs_env.precipitationCal.sel(mcs_phase='Mature')
tmp2 = mcs_env.tb.sel(mcs_phase='Mature')
conv_pix = tmp.where(((tmp > 0.5) & (tmp2 < 241)))
strat_pix = tmp.where(((tmp < 0.5) & (tmp2 < 241)))

# %%
conv_pix.plot()
mcs_env.cloudtracknumber_nomergesplit.sel(mcs_phase='Mature').plot.contour()

# %%
strat_pix.plot()
mcs_env.cloudtracknumber_nomergesplit.sel(mcs_phase='Mature').plot.contour()
