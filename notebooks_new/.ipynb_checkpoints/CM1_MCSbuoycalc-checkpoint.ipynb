# %%
import os
import sys
import xarray as xr
import numpy as np
import pandas as pd
from numba import jit, vectorize, float64

import matplotlib
from matplotlib import pyplot as plt
from datetime import datetime
from pathlib import Path

import warnings

# %%
warnings.filterwarnings('ignore')

# %%
@jit(nopython=False)
def es_calc_bolton(temp):
    # in hPa

    tmelt  = 273.15
    tempc = temp - tmelt
    es = 6.112*np.exp(17.67*tempc/(243.5+tempc))

    return es

# %%
@jit(nopython=False)
def es_calc(temp):
    """
    temp [x,p]
    """
    tmelt  = 273.15

    c0=0.6105851e+03
    c1=0.4440316e+02
    c2=0.1430341e+01
    c3=0.2641412e-01
    c4=0.2995057e-03
    c5=0.2031998e-05
    c6=0.6936113e-08
    c7=0.2564861e-11
    c8=-.3704404e-13

    tempc = temp - tmelt
    tempcorig = tempc

    #if tempc < -80:
    es_ltn80c = es_calc_bolton(temp)
    es_ltn80c = np.where(tempc < -80, es_ltn80c, 0)

    #else:
    es = c0+tempc*(c1+tempc*(c2+tempc*(c3+tempc*(c4+tempc*(c5+tempc*(c6+tempc*(c7+tempc*c8)))))))
    es_gtn80c = es/100
    es_gtn80c = np.where(tempc >= -80, es_gtn80c, 0)

    # complete es
    es = es_ltn80c + es_gtn80c

    return es

# %%
@jit(nopython=False)
def qs_calc(temp, p_level):

    tmelt  = 273.15
    RV=461.5
    RD=287.04

    EPS=RD/RV

    press = p_level * 100. # in Pa
    tempc = temp - tmelt

    es=es_calc(temp) # [x,y,p]
    es=es * 100. #hPa

    qs = (EPS * es) / (press + ((EPS-1.)*es))

    return qs

# %%
@jit(nopython=False)
def theta_e_calc(temp, q, p_level):

    # following the definitions in Bolton (1980): the calculation of equivalent potential temperature

    pref = 100000.
    tmelt  = 273.15
    CPD=1005.7
    CPV=1870.0
    CPVMCL=2320.0
    RV=461.5
    RD=287.04
    EPS=RD/RV
    ALV0=2.501E6

    press = p_level * 100. # in Pa
    tempc = temp - tmelt # in C

    r = q / (1. - q)

    # get ev in hPa
    ev_hPa = p_level * r / (EPS + r) # hpa

    #get TL
    TL = (2840. / ((3.5*np.log(temp)) - (np.log(ev_hPa)) - 4.805)) + 55.

    #calc chi_e:
    chi_e = 0.2854 * (1. - (0.28 * r))

    theta_e = temp * np.power((pref / press),chi_e) * np.exp(((3.376/TL) - 0.00254) * r * 1000 * (1. + (0.81 * r)))

    return theta_e

# %%
@jit(nopython=False)
def layer_average_trapz(var_1d, p_1d):

    var_sum = 0
    for z in range(1,len(var_1d)):
        dx = p_1d[z] - p_1d[z-1]
        var_sum += 1/2*(var_1d[z-1]+var_1d[z])*dx

    return var_sum/(p_1d[-1]-p_1d[0])

# %%
@jit(nopython=True)
def BL_measures_calc_zcord(T, q, sp, T2m, q2m, prs, xh, yh):

    # constants
    Lv = 2.5e6 # (J/kg)
    g = 9.81 # (kg/m^2)
    cpd = 1004 # (J/kg/K)
    p0 = 1000  # (hPa)
    Rd = 287.15 # (J/kg)

    # find pbl top (100 hPa above the surface)
    # pbl_top_level = find_pbl_top_level(sp, p_level, pbl_depth=100)

    # allocate 2-D layer-averaged thetae components
    len_y = T.shape[1]
    len_x = T.shape[2]

    thetae_bl_array = np.zeros((len_y, len_x))*np.nan
    thetae_lt_array = np.copy(thetae_bl_array)
    thetae_sat_lt_array = np.copy(thetae_bl_array)

    # loop for lat-lon grids
    for j in np.arange(len_y):
        for i in np.arange(len_x):

            sfc_p = sp[j,i] # surface pressure
            #pbl_p = pbl_top_level[j,i] # pbl top pressure
            pbl_p = sfc_p - 100
            p_level = prs[:,j,i]

            if pbl_p >= 500: # low-troposphere upper bound greater than 500 hPa

                T_at_sf = T2m[j,i]
                q_at_sf = q2m[j,i]

                idp_sfc = np.argmin(np.abs(sfc_p - p_level))
                if (idp_sfc == len(p_level)-1) and (sfc_p >= 1000): # if surface pressure >= 1000 hPa
                    T_above_sf = T[:,j,i]
                    q_above_sf = q[:,j,i]
                    p_above_sf = p_level[:]

                    # reconstruct the entirle T, q profiles by adding surface quantities
                    T_1d = np.hstack((np.array([T_at_sf]), np.flip(T_above_sf)))
                    q_1d = np.hstack((np.array([q_at_sf]), np.flip(q_above_sf)))
                    pressure_1d = np.hstack((np.array([sfc_p]), np.flip(p_above_sf)))

                elif (idp_sfc == len(p_level)-1) and (sfc_p < 1000): # surface pressure < 1000 hPa
                    T_above_sf = T[:idp_sfc,j,i] #[top->1000]
                    q_above_sf = q[:idp_sfc,j,i]
                    p_above_sf = p_level[:idp_sfc]

                    # reconstruct the entirle T, q profiles by adding surface quantities
                    T_1d = np.hstack((np.array([T_at_sf]), np.flip(T_above_sf)))
                    q_1d = np.hstack((np.array([q_at_sf]), np.flip(q_above_sf)))
                    pressure_1d = np.hstack((np.array([sfc_p]), np.flip(p_above_sf)))

                else:
                    T_above_sf = T[:idp_sfc+1,j,i]
                    q_above_sf = q[:idp_sfc+1,j,i]
                    p_above_sf = p_level[:idp_sfc+1]

                    # reconstruct the entirle T, q profiles by adding surface quantities
                    T_1d = np.hstack((np.array([T_at_sf]), np.flip(T_above_sf)))
                    q_1d = np.hstack((np.array([q_at_sf]), np.flip(q_above_sf)))
                    pressure_1d = np.hstack((np.array([sfc_p]), np.flip(p_above_sf)))
                    if np.any(np.diff(pressure_1d) > 0):
                        T_1d = np.hstack((np.array([T_at_sf]), np.flip(T_above_sf[:len(p_level)-1])))
                        q_1d = np.hstack((np.array([q_at_sf]), np.flip(q_above_sf[:len(p_level)-1])))
                        pressure_1d = np.hstack((np.array([sfc_p]), np.flip(p_above_sf[:len(p_level)-1])))

                # interpolated points at the pbl top and 500 hPa into P_sfc_to_100
                pressure_val = np.hstack((pressure_1d, np.array([pbl_p]), np.array([500])))
                pressure_val = np.unique(np.sort(pressure_val))[::-1] # new pressure coord including these two levels
                T_1d_interp = np.interp(pressure_val[::-1], pressure_1d[::-1], T_1d[::-1])[::-1]
                q_1d_interp = np.interp(pressure_val[::-1], pressure_1d[::-1], q_1d[::-1])[::-1]

                # splitting into boundary layer and lower free troposphere with decreasing the p_coord
                # 1. boundary layer, bl
                idp_pbl = np.where(pressure_val == pbl_p)[0][0]
                q_bl = q_1d_interp[:idp_pbl+1]
                T_bl = T_1d_interp[:idp_pbl+1]
                p_bl = pressure_val[:idp_pbl+1]
                
                # 2. lower free troposphere, lt
                idp_500 = np.where(pressure_val == 500.)[0][0]
                q_lt = q_1d_interp[idp_pbl:idp_500+1]
                T_lt = T_1d_interp[idp_pbl:idp_500+1]
                p_lt = pressure_val[idp_pbl:idp_500+1]

                # calculating layer-averaged thetae components
                #delta_pb = p_bl[0] - p_bl[-1]
                #delta_pl = (sfc_p - 500.) - delta_pb
                thetae_bl = theta_e_calc(T_bl, q_bl, p_bl)
                thetae_bl_avg = layer_average_trapz(np.flip(thetae_bl), np.flip(p_bl)) # negative sign b.c. decreasing p
                #thetae_bl_avg = np.nanmean(thetae_bl)
                thetae_lt = theta_e_calc(T_lt, q_lt, p_lt)
                thetae_lt_avg = layer_average_trapz(np.flip(thetae_lt), np.flip(p_lt))
                #thetae_lt_avg = np.nanmean(thetae_lt)
                qsat_lt = qs_calc(T_lt, p_lt)
                thetae_sat_lt = theta_e_calc(T_lt, qsat_lt, p_lt)
                thetae_sat_lt_avg = layer_average_trapz(np.flip(thetae_sat_lt), np.flip(p_lt))
                #thetae_sat_lt_avg = np.nanmean(thetae_sat_lt)

                thetae_bl_array[j,i] = thetae_bl_avg
                thetae_lt_array[j,i] = thetae_lt_avg
                thetae_sat_lt_array[j,i] = thetae_sat_lt_avg

            else: # some montain areas with PBL lower than 500 hPa

                thetae_bl_array[j,i] = np.nan
                thetae_lt_array[j,i] = np.nan
                thetae_sat_lt_array[j,i] = np.nan

    # calculate buoyancy estimates
    # 2-d weighting parameters for pbl and lt
    delta_pl=sp-100-500
    delta_pb=100
    wb=(delta_pb/delta_pl)*np.log((delta_pl+delta_pb)/delta_pb)
    wl=1-wb
    
    # calculate buoyancy estimate
    Buoy_CAPE = (9.81/(340*3)) * wb * ((thetae_bl_array-thetae_sat_lt_array)/thetae_sat_lt_array) * 340
    Buoy_SUBSAT = (9.81/(340*3))* wl * ((thetae_sat_lt_array-thetae_lt_array)/thetae_sat_lt_array) * 340
    Buoy_TOT = Buoy_CAPE - Buoy_SUBSAT
    
    return (Buoy_CAPE, Buoy_SUBSAT, Buoy_TOT, thetae_bl_array, thetae_lt_array, thetae_sat_lt_array)

# %%
def olr_to_tb(OLR):
    """
    Convert OLR to IR brightness temperature.

    Args:
        OLR: np.array
            Outgoing longwave radiation

    Returns:
        tb: np.array
            Brightness temperature
    """
    # Calculate brightness temperature
    # (1984) as given in Yang and Slingo (2001)
    # Tf = tb(a+b*Tb) where a = 1.228 and b = -1.106e-3 K^-1
    # OLR = sigma*Tf^4
    # where sigma = Stefan-Boltzmann constant = 5.67x10^-8 W m^-2 K^-4
    a = 1.228
    b = -1.106e-3
    sigma = 5.67e-8 # W m^-2 K^-4
    tf = (OLR/sigma)**0.25
    tb = (-a + np.sqrt(a**2 + 4*b*tf))/(2*b)
    return tb

# %%
cm1_out = Path('/scratch/wmtsai/cm1_model/CM1_MCS/mcs_idealized_diurnal_LD/run')
files = sorted(list(cm1_out.glob('cm1out_*.nc')))
data = xr.open_dataset(files[250])

# %%
theta = data['th']
p0 = 1000
prs = data['prs']
data['T'] = data['th']*(p0/(prs/100))**(-287.15/1004)

# %%
# %%time
T = data['T'].values.squeeze()
q = data['qv'].values.squeeze()
sp = data['prs'].isel(zh=0).values.squeeze()
T2m = data['T'].isel(zh=0).values.squeeze() # first level 
q2m = data['qv'].isel(zh=0).values.squeeze() # first level
prs = (data['prs']/100).values.squeeze()
xh = data.xh.values
yh = data.yh.values

(Buoy_CAPE, Buoy_SUBSAT, Buoy_TOT, thetae_bl_array, thetae_lt_array, thetae_sat_lt_array) = BL_measures_calc_zcord(T, q, sp, T2m, q2m, prs, xh, yh)

# write out as xarray
ds = xr.Dataset(data_vars=dict(
                Buoy_CAPE = (['y','x'], Buoy_CAPE),
                Buoy_SUBSAT = (['y','x'], Buoy_SUBSAT),
                Buoy_TOT = (['y','x'], Buoy_TOT),
                thetae_bl = (['y','x'], thetae_bl_array),
                thetae_lt = (['y','x'], thetae_lt_array),
                thetae_sat_lt = (['y','x'], thetae_sat_lt_array)),

                coords=dict(x = (['x'], xh),
                            y = (['y'], yh))
               )
# Out:
# CPU times: user 5.08 s, sys: 31.3 ms, total: 5.11 s
# Wall time: 5.11 s

# %%
fig, ax = plt.subplots(1,1,figsize=(8,4))
(3600*data['prate'].isel(time=0)).plot.contour(levels=[10,20,30],colors=['m'],linewidths=0.5)
cp = ((340*3/9.8)*ds.Buoy_TOT).plot(vmin=-10, vmax=5, cmap='jet')
cp.cmap.set_under('w')

# %%
fig, ax = plt.subplots(1,1,figsize=(8,4))
olr_to_tb(data.lwupt).plot(ax=ax, vmax=241, cmap='binary');

# %%
# %%time
# buoyancy-precip relationship in CM1
bins_bl = np.arange(-30,5,0.5)
samples = np.zeros(len(bins_bl)-1)
prec_sum = np.copy(samples)

cm1_out = Path('/scratch/wmtsai/cm1_model/CM1_MCS/mcs_idealized_diurnal_LD/run')
files = sorted(list(cm1_out.glob('cm1out_00*.nc')))
for file in files[180:]:
    print('processing file: {}'.format(file.name))
    data = xr.open_dataset(file)
    theta = data['th']
    p0 = 1000
    prs = data['prs']
    data['T'] = data['th']*(p0/(prs/100))**(-287.15/1004)
    
    T = data['T'].values.squeeze()
    q = data['qv'].values.squeeze()
    sp = data['prs'].isel(zh=0).values.squeeze()
    T2m = data['T'].isel(zh=0).values.squeeze() # first level 
    q2m = data['qv'].isel(zh=0).values.squeeze() # first level
    prs = (data['prs']/100).values.squeeze()
    xh = data.xh.values
    yh = data.yh.values
    
    # calculate buoyancy 
    (Buoy_CAPE, Buoy_SUBSAT, Buoy_TOT, thetae_bl_array
     , thetae_lt_array, thetae_sat_lt_array) = BL_measures_calc_zcord(T, q, sp, T2m, q2m, prs, xh, yh)
    # write out as xarray
    ds = xr.Dataset(data_vars=dict(
                    Buoy_CAPE = (['y','x'], Buoy_CAPE),
                    Buoy_SUBSAT = (['y','x'], Buoy_SUBSAT),
                    Buoy_TOT = (['y','x'], Buoy_TOT),
                    thetae_bl = (['y','x'], thetae_bl_array),
                    thetae_lt = (['y','x'], thetae_lt_array),
                    thetae_sat_lt = (['y','x'], thetae_sat_lt_array)),

                    coords=dict(x = (['x'], xh),
                                y = (['y'], yh))
                   )

    bl = (340*3)/9.8*ds.Buoy_TOT
    prec = 3600*data.prate.isel(time=0)
    
    # regrid into 0.25-deg
    
    bl_1d = bl.values.ravel()
    prec_1d = prec.values.ravel()

    for i in range(len(bins_bl)-1):
        idx = np.where(np.logical_and(bl_1d >= bins_bl[i], bl_1d < bins_bl[i+1]))[0]
        samples[i] += len(idx)
        prec_sum[i] += np.sum(prec_1d[idx])
# Out:
# processing file: cm1out_000181.nc
# processing file: cm1out_000182.nc
# processing file: cm1out_000183.nc
# processing file: cm1out_000184.nc
# processing file: cm1out_000185.nc
# processing file: cm1out_000186.nc
# processing file: cm1out_000187.nc
# processing file: cm1out_000188.nc
# processing file: cm1out_000189.nc
# processing file: cm1out_000190.nc
# processing file: cm1out_000191.nc
# processing file: cm1out_000192.nc
# processing file: cm1out_000193.nc
# processing file: cm1out_000194.nc
# processing file: cm1out_000195.nc
# processing file: cm1out_000196.nc
# processing file: cm1out_000197.nc
# processing file: cm1out_000198.nc
# processing file: cm1out_000199.nc
# processing file: cm1out_000200.nc
# processing file: cm1out_000201.nc
# processing file: cm1out_000202.nc
# processing file: cm1out_000203.nc
# processing file: cm1out_000204.nc
# processing file: cm1out_000205.nc
# processing file: cm1out_000206.nc
# processing file: cm1out_000207.nc
# processing file: cm1out_000208.nc
# processing file: cm1out_000209.nc
# processing file: cm1out_000210.nc
# processing file: cm1out_000211.nc
# processing file: cm1out_000212.nc
# processing file: cm1out_000213.nc
# processing file: cm1out_000214.nc
# processing file: cm1out_000215.nc
# processing file: cm1out_000216.nc
# processing file: cm1out_000217.nc
# processing file: cm1out_000218.nc
# processing file: cm1out_000219.nc
# processing file: cm1out_000220.nc
# processing file: cm1out_000221.nc
# processing file: cm1out_000222.nc
# processing file: cm1out_000223.nc
# processing file: cm1out_000224.nc
# processing file: cm1out_000225.nc
# processing file: cm1out_000226.nc
# processing file: cm1out_000227.nc
# processing file: cm1out_000228.nc
# processing file: cm1out_000229.nc
# processing file: cm1out_000230.nc
# processing file: cm1out_000231.nc
# processing file: cm1out_000232.nc
# processing file: cm1out_000233.nc
# processing file: cm1out_000234.nc
# processing file: cm1out_000235.nc
# processing file: cm1out_000236.nc
# processing file: cm1out_000237.nc
# processing file: cm1out_000238.nc
# processing file: cm1out_000239.nc
# processing file: cm1out_000240.nc
# processing file: cm1out_000241.nc
# processing file: cm1out_000242.nc
# processing file: cm1out_000243.nc
# processing file: cm1out_000244.nc
# processing file: cm1out_000245.nc
# processing file: cm1out_000246.nc
# processing file: cm1out_000247.nc
# processing file: cm1out_000248.nc
# processing file: cm1out_000249.nc
# processing file: cm1out_000250.nc
# processing file: cm1out_000251.nc
# processing file: cm1out_000252.nc
# processing file: cm1out_000253.nc
# processing file: cm1out_000254.nc
# processing file: cm1out_000255.nc
# processing file: cm1out_000256.nc
# processing file: cm1out_000257.nc
# processing file: cm1out_000258.nc
# processing file: cm1out_000259.nc
# processing file: cm1out_000260.nc
# processing file: cm1out_000261.nc
# processing file: cm1out_000262.nc
# processing file: cm1out_000263.nc
# processing file: cm1out_000264.nc
# processing file: cm1out_000265.nc
# processing file: cm1out_000266.nc
# processing file: cm1out_000267.nc
# processing file: cm1out_000268.nc
# processing file: cm1out_000269.nc
# processing file: cm1out_000270.nc
# processing file: cm1out_000271.nc
# processing file: cm1out_000272.nc
# processing file: cm1out_000273.nc
# processing file: cm1out_000274.nc
# processing file: cm1out_000275.nc
# processing file: cm1out_000276.nc
# processing file: cm1out_000277.nc
# processing file: cm1out_000278.nc
# processing file: cm1out_000279.nc
# processing file: cm1out_000280.nc
# processing file: cm1out_000281.nc
# processing file: cm1out_000282.nc
# processing file: cm1out_000283.nc
# processing file: cm1out_000284.nc
# processing file: cm1out_000285.nc
# processing file: cm1out_000286.nc
# processing file: cm1out_000287.nc
# processing file: cm1out_000288.nc
# processing file: cm1out_000289.nc
# processing file: cm1out_000290.nc
# processing file: cm1out_000291.nc
# processing file: cm1out_000292.nc
# processing file: cm1out_000293.nc
# processing file: cm1out_000294.nc
# processing file: cm1out_000295.nc
# processing file: cm1out_000296.nc
# processing file: cm1out_000297.nc
# processing file: cm1out_000298.nc
# processing file: cm1out_000299.nc
# processing file: cm1out_000300.nc
# processing file: cm1out_000301.nc
# processing file: cm1out_000302.nc
# processing file: cm1out_000303.nc
# processing file: cm1out_000304.nc
# processing file: cm1out_000305.nc
# processing file: cm1out_000306.nc
# processing file: cm1out_000307.nc
# processing file: cm1out_000308.nc
# processing file: cm1out_000309.nc
# processing file: cm1out_000310.nc
# processing file: cm1out_000311.nc
# processing file: cm1out_000312.nc
# processing file: cm1out_000313.nc
# processing file: cm1out_000314.nc
# processing file: cm1out_000315.nc
# processing file: cm1out_000316.nc
# processing file: cm1out_000317.nc
# processing file: cm1out_000318.nc
# processing file: cm1out_000319.nc
# processing file: cm1out_000320.nc
# processing file: cm1out_000321.nc
# processing file: cm1out_000322.nc
# processing file: cm1out_000323.nc
# processing file: cm1out_000324.nc
# processing file: cm1out_000325.nc
# processing file: cm1out_000326.nc
# processing file: cm1out_000327.nc
# processing file: cm1out_000328.nc
# processing file: cm1out_000329.nc
# processing file: cm1out_000330.nc
# processing file: cm1out_000331.nc
# processing file: cm1out_000332.nc
# processing file: cm1out_000333.nc
# processing file: cm1out_000334.nc
# processing file: cm1out_000335.nc
# processing file: cm1out_000336.nc
# processing file: cm1out_000337.nc
# processing file: cm1out_000338.nc
# processing file: cm1out_000339.nc
# processing file: cm1out_000340.nc
# processing file: cm1out_000341.nc
# processing file: cm1out_000342.nc
# processing file: cm1out_000343.nc
# processing file: cm1out_000344.nc
# processing file: cm1out_000345.nc
# processing file: cm1out_000346.nc
# processing file: cm1out_000347.nc
# processing file: cm1out_000348.nc
# processing file: cm1out_000349.nc
# processing file: cm1out_000350.nc
# processing file: cm1out_000351.nc
# processing file: cm1out_000352.nc
# processing file: cm1out_000353.nc
# processing file: cm1out_000354.nc
# processing file: cm1out_000355.nc
# processing file: cm1out_000356.nc
# processing file: cm1out_000357.nc
# processing file: cm1out_000358.nc
# processing file: cm1out_000359.nc
# processing file: cm1out_000360.nc
# processing file: cm1out_000361.nc
# CPU times: user 4min 59s, sys: 7.84 s, total: 5min 6s
# Wall time: 5min 6s

# %%
# plot conditional precipitation
plt.plot(bins_bl[:-1], prec_sum/samples, marker='*')
