# %% [markdown]
# ### font-test

# %%
import os
import sys
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties

import warnings

# %%
for fontpath in font_manager.findSystemFonts(fontpaths='/home/wmtsai/anaconda3/fonts', fontext='ttf'):
    if 'arial'.lower() in fontpath.lower():
        print(fontpath)
# Out:
# /home/wmtsai/anaconda3/fonts/ariali.ttf
# /home/wmtsai/anaconda3/fonts/arial.ttf
# /home/wmtsai/anaconda3/fonts/arialbi.ttf
# /home/wmtsai/anaconda3/fonts/arialbd.ttf

# %%
# get normal font and store it in `fira_sans_regular`
personal_path = '/home/wmtsai/anaconda3/fonts/'
font_path = personal_path + 'arial.ttf'
arial_reg = FontProperties(fname=font_path)

# %%
arial_reg

# %%
matplotlib.rcParams['font.sans-serif'] = 'Arial'

# %%
plt.figure(figsize=(8, 6))
plt.scatter([1, 2, 3, 4], [1, 2, 3, 4], s=500, color="darkcyan")

plt.text(
    2.2, 2, # positions
    "Text with Arial (normal)",
    font=arial_reg,
    fontsize=20
)

plt.text(
    1, 3, # positions
    "Text with Dejavu Sans (bold)",
    fontsize=20
)
# Out:
# Text(1, 3, 'Text with Dejavu Sans (bold)')
